# %% [markdown]
# <a href="https://colab.research.google.com/github/mathuscm/Criptomoedas-m5/blob/main/Relat%C3%B3rio_Cryptalytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Relatório de análise das criptomoedas

# %% [markdown]
# Este relatório oferece uma análise abrangente dos valores das principais criptomoedas ao longo de um período de tempo que abrange vários anos, com foco em explorar tendências, médias, flutuações sazonais e relações entre esses ativos digitais. Durante a análise, examinamos como os valores das criptomoedas se comportaram, observando tanto as tendências de aumento quanto de queda. Calculamos as médias desses valores, identificamos anos de maiores oscilações e investigamos se há tendências associadas aos dias da semana. Além disso, destacamos as moedas que se destacaram em termos de valorização e aquelas que tiveram desempenho menos favorável com base na série histórica. Por fim, exploramos a existência de correlações entre os valores de todas as criptomoedas, oferecendo uma visão completa do mercado cripto durante o período analisado.

# %% [markdown]
# # 1. Como se comportaram os valores para todas as criptomoedas? Os valores tiveram uma tendência de queda ou de aumento?
# - Com base nas médias de preços de abertura (Open) e de fechamento (Close) das criptomoedas durante o período de 2014 a 2021, podemos observar o seguinte comportamento geral:
#
#  - A maioria das criptomoedas apresentou uma tendência de aumento em seus valores médios de abertura e fechamento ao longo desse período.
#  - Portanto, podemos afirmar que, em média, as criptomoedas consideradas tiveram uma tendência de aumento de valor durante o período mencionado, embora tenham ocorrido flutuações ao longo do tempo. É importante destacar que essa é uma análise simplificada com base em médias e que o comportamento individual das criptomoedas pode variar significativamente.
#
# -📈 Binância (BNB) :
#   - Média Abertura: $ 52,03,
#
#   - Fechamento médio: $ 52,25.
#
#   ✅ Binance (BNB) : O valor médio de abertura (Open) e de fechamento (Close)  da Binance (BNB) tendeu a aumentar ao longo do tempo durante o período considerado. Houve flutuações e correções temporárias, mas, em média, a tendência foi de aumento.
#
# -📈 Bitcoin (BTC) :
#  - Média Abertura: $ 6.700,15
#
#  - Fechamento médio: $ 6.711,29.
#
#  ✅ O Bitcoin (BTC) apresentou uma tendência geral de aumento significativo durante o período. Embora tenha havido picos e quedas notáveis, como em 2017 e 2018.O valor médio de abertura e fechamento aumentou consideravelmente.
#
# -📈 XRP (XRP) :
#   - Média Abertura: $ 0,24
#
#   - Fechamento médio: $ 0,24.
#
#  ✅O XRP (XRP) teve um comportamento misto ao longo do período. Experimentou valorizações notáveis, especialmente em 2017, mas também enfrentou desafios regulatórios que afetaram seu preço. Em média, seu valor manteve-se relativamente estável.
#
# -📈 Chainlink  (LINK) :
#   - Média Abertura: $ 6,29
#
#   - Fechamento médio: $ 6,31.
#
#   ✅O Chainlink (LINK) mostrou uma tendência de aumento de valor durante o período, com variações ao longo do tempo.
#
# -📈 Cosmos (ÁTOMO) :
#   - Média Abertura: $ 6,76
#
#   - Fechamento médio: $ 6,77.
#
#   ✅ O Cosmos (ATOM) teve uma tendência geral de aumento de valor, com flutuações moderadas.
#
# -📈EOS (EOS) :
#
#   - Média Abertura: $ 4,62
#
#   - Fechamento médio: $ 4,62.
#
#   ✅ O EOS (EOS) manteve um valor relativamente estável durante o período, com poucas oscilações significativas.
#
# -📈 Ethereum (ETH) :
#   - Média Abertura: $ 382,88
#
#   - Fechamento médio: $ 383,91.
#
#   ✅ O Ethereum (ETH) também apresentou uma tendência de aumento de valor, impulsionada pelo seu uso em contratos inteligentes e DeFi.
# -📈 Polkadot (DOT) :
#   - Média Abertura: $ 18,11
#
#   - Fechamento médio: $ 18,14.
#
#   ✅ O Polkadot (DOT), embora mais recente, demonstrou uma tendência de aumento de valor, refletindo o interesse em sua tecnologia de interoperabilidade.
#
# -📈 USDCoin (USDC) :
#   - Média Abertura: $ 1,00
#
#   - Fechamento médio: $ 1,00.
#
#   ✅ O USD Coin (USDC) é uma stablecoin, projetada para manter sua estabilidade em relação ao dólar dos EUA, portanto, sua variação percentual é mínima.
#
# -📈 Aave (AAVE) :
#   - Média Abertura: $ 254,51
#
#   - Fechamento médio: $ 255,53.
#   ✅ O Aave (AAVE) apresentou uma tendência de aumento de valor ao longo do período, refletindo o crescimento do ecossistema DeFi.
#
# 🎯 Essas médias representam os preços de abertura e fechamento médios durante o período de 2014 a 2021. É importante notar que esses valores podem ter flutuado significativamente ao longo dos anos, refletindo a volatilidade do mercado de criptomoedas. Investidores e comerciantes geralmente monitoram essas flutuações para tomar decisões informadas de compra e venda.

# %% [markdown]
# # 2. Quais os valores médios para todas as criptomoedas?
# - Para calcular os valores médios das principais criptomoedas, compilamos uma lista das moedas mais relevantes, incluindo o Bitcoin, Ethereum, Aave, Binance Coin, Polkadot e outras. Em seguida, determinamos o valor médio de cada uma ao longo de todo o período disponível no relatório. Esses valores médios nos fornecem uma visão abrangente das cotações dessas criptomoedas, revelando suas posições relativas no mercado em relação a seus preços médios durante esse período.

# %% [markdown]
# <img src="https://i.imgur.com/ZBxvDfT.png" height='400px'/>

# %% [markdown]
# 1. **Bitcoin (BTC) - Valor Médio $6.711,29:** O Bitcoin mantém sua posição de liderança como a criptomoeda mais valorizada, com um valor médio significativo. Sua notável valorização reflete seu status como a primeira e mais reconhecida criptomoeda do mundo.
#
# 2. **Ethereum (ETH) - Valor Médio $383,91:** O Ethereum é a segunda maior criptomoeda por capitalização de mercado e continua a desempenhar um papel fundamental no mercado devido à sua plataforma de contratos inteligentes e aplicativos descentralizados (DApps).
#
# 3. **Aave (AAVE) - Valor Médio $255,53:** Aave é uma criptomoeda de “Finanças Descentralizadas” (DeFi) em destaque, com um valor médio considerável. Sua capacidade de facilitar empréstimos e de emprestar no espaço DeFi o torna uma escolha popular entre os investidores.
#
# 4. **Binance Coin (BNB) - Valor Médio $52,25:** A Binance Coin é a criptomoeda nativa da exchange de criptomoedas Binance, e seu valor médio reflete sua utilidade na plataforma Binance, onde os detentores de BNB podem obter benefícios como descontos em taxas de negociação.
#
# 5. **Polkadot (DOT) - Valor Médio $18,14:** Polkadot é uma plataforma que visa a interoperabilidade entre blockchains, com um valor médio sólido. Isso destaca seu papel no ecossistema blockchain como uma solução inovadora.
#
# 6. **Cosmos (ATOM) - Valor Médio $6,77:** Cosmos é outra plataforma que busca a interoperabilidade entre blockchains, e seu valor médio indica que é uma escolha viável para aqueles interessados na comunicação eficaz entre diferentes redes de blockchain.
#
# 7. **Chainlink (LINK) - Valor Médio $6,31:** Chainlink é um protagonista no espaço de oracles, conectando contratos inteligentes a dados do mundo real. Seu valor médio reflete a importância dos oracles no ecossistema blockchain.
#
# 8. **EOS (EOS) - Valor Médio $4,62:** EOS é conhecido por sua escalabilidade e é usado para criar aplicativos descentralizados. Seu valor médio mostra que ainda é uma escolha relevante para desenvolvedores de DApps.
#
# 9. **USD Coin (USDC) Valor Médio $$ 1,00:** O USD Coin é uma criptomoeda estável ancorada ao dólar dos EUA, projetada para manter um valor constante próximo a $1. Sua estabilidade é sua característica distintiva.
#
# 10. **XRP (XRP) - Valor Médio $0,24:** O XRP é usado principalmente para transferências de dinheiro transfronteiriças, com um valor médio que o torna uma escolha eficiente para soluções de pagamento global.

# %% [markdown]
# #3. Em quais anos houve quedas e valorizações?

# %% [markdown]
# Para realizar esta análise as moedas foram separadas em dois quadrantes contendo cinco em cada, medindo a linha temporal desde o surgimento delas até o marco de 2021.
#
# Esta divisão foi realizada, primeiramente, para facilitar a visualização mais limpa das informações, e depois, para enquadrar melhor o período de surgimento/início da operação de cada moeda dentro de uma margem.
#
# A criação dos dois gráficos foram feitas com base nos valores registrados em "Fechamento" disponível na tabela, e para verificar as altas e as quedas do fechamento, foi efetuada a média para indentificar os preços nos quais cada cripto fechou o ano, assim pode-se tirar a base de valorização.

# %% [markdown]
# ![valorizado.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# O primeiro gráfico nos mostra o balanço das moedas ChainLink (LINK), Cosmos, EOS, Polkadot e USDCoin.
# * Da data de criação/lançamento destas criptos, durante seu tempo de vida, nota-se que 2021 foi o ano de maior valor para ChainLink, Polkadot e Cosmos.
# * Para a EOS, seu pico foi no ano de 2018 com tendência de congelamento após o ano de 2019
# * USDCoin manteve linearidade na estabilidade do seu preço.
#
# Enquanto as demais criptomoedas variam suas tendências, a USDCoin se mantém constante. Isso ocorre porque ela é uma moeda pareada ao dólar só que funcionando em carteiras digitais e com o sistema blockchain, então, técnicamente, seu valor se estabiliza no preço da moeda norte-americana.
#
# A curva da EOS tem alta logo no início de sua operação e depois, uma queda suave com predição de estagnar. Há alguns fatores que podem dar significado a este movimento. A EOS surgiu com um padrão diferenciado de tecnologia blockchain descentralizada, a fácil operação e utilização de tokens (ativos que possuem valor comercial) da moeda gerou bilhões para sua receita.
#
# O movimento de decaída da EOS se deve a problemas internos em relação ao desenvolvimento contínuo da sua ferramenta base (EOSIO), causando falhas e devido a falta de recursos, causou queda na cripto, até 2021, em que surgiu a ENF (EOS Network Foundation) com nova proposta para levantar a moeda.
#
# As criptomedas ChainLink, Polkadot e Cosmos seguem a tendência de subida do gráfico, quase de maneira simultânea. O movimento da Cosmos pode estar ligado ao seu modo de operação, é uma cripto interoperadore, que permite transferencia entre outras moedas, o que pode ter valorizado e permitido a escalabilidade. Já a ChainLink (LINK) e a Polkadot (DOT) iniciaram como plataformas de transação de criptomoedas para superar 'gargalos' deste mercado, como a de criar pontes  entre criptos e a facilidade para os usuários, antes de iniciarem suas operações com moeda própria, o que em si foi um facilitador e assim que suas moedas foram lançadas houve supervalorização.

# %% [markdown]
# O segundo gráfico nos mostra o balanço das moedas Aave (AAVE), Binance Coin (BNB), Bitcoin (BTC), Ethereum (ETH) e XRP (XRP).
# * As criptos Bitcoin, Ethereum, Aave e Binance, respectivamente, tiveram suas cotações mais altas em 2021;
# * XRP mantém sua linearidade abaixo de $1 dólar, sua variação é imperceptível.
#
# A criptomoeda Aave é recente e já alcançou um pico de sucesso 1 ano após o início de operação. Um ponto que pode justificar a crescente é que a plataforma de investimento (o usuário recebe juros por aplicação) também permite empréstimos em troca de pagar taxas.
#
# O fato da XRP não demonstrar curvas em sua linha pode estar ligado a investigação da SEC (Securities and Exchange Commission, Comissão de Segurança dos bancos de Criptoativos) sobre a suspeita da unidade ter negociado acordos com entidades não registradas na SEC para elencar a XRP no intuito de atingir métricas de volume e poder valorizar a cripto. Esta negociação com mercados secundários podem justificar o impacto na estagnação da margem de preço.
#
# A Binance, inicialmente uma corretora de moedas, começou sua operação em 2017 na China, sendo um ano não tão bom devido as mudanças internas na economia chinesa em que o governo baniu a atividade de criptoativos no país asiático.
# Assim como Bitcoin e Ethereum, e outras moedas, teve ascensão no mercado em 2021, e este aumento pode estar relacionado à época em que o mundo estava, fragilizado pelas consequências da Covid-19, vários setores do mercado monetário comum sofrendo com inflações e ofertas de créditos demasiada, e isto pode ter impulsionado seu crescimento devido ao valor neste momento e a busca por estabilidade e segurança em investimentos pelos usuários, além de que a Binance também oferece aos investidores retorno em juros, além da opção de negociar várias moedas dentro de sua plataforma criptofinanceira.
#
# O Bitcoin é a criptomoeda que mais sofre oscilação, no entanto, suas altas sempre são maiores que a queda. Esta ocorrência pode estar dretamente relacionada ao motivo do Bitcoin ser uma moeda limitada mundialmente. Ou seja, ela foi criada com um limite, 21 milhões de moedas, apenas. Por estas vias, ela se torna uma fonte de "ouro" e seu funcionamento entra na questão da oferta e demanda no mercado, por isso, quanto mais moedas são "mineiradas" e entram na carteira de alguém, menos Bitcoins existem fazendo com que se tornem cada vez mais caros.
#
# Ao examinar as curvas da criptomoeda Ethereum, é possível notar com ela também sofre com oscilações, menos que o Bitcoin, mas ainda assim tem suas fases. Como todo o restante do mercado de moedas digitais que se beneficiaram em 2021 com a ascensão do mercado e mais adesão no momento pandêmico, a elevação da Ethereum, em sua particularidade, pode estar relacionada aos NFTs (Tokens Não Fungíveis), que são itens/símbolos exclusivos e não podem ser duplicados. O movimento de NFTs também surgiu em 2021 e ele é negociado em criptomoedas e criado dentro das plataformas exchange (corretoras de criptomoedas), e a maior delas é a Ethereum.

# %% [markdown]
# # 4. Existe alguma tendência de aumento ou queda dos valores pelo dia da semana?
#
# <img src="https://i.imgur.com/p4hQdqW.png" height='400px'/>
#
#  - Segunda-feira (Seg): A maioria das moedas parece ter uma tendência positiva no início da semana, com valores
#    médios acima da média semanal.
#
#  - Terça-feira (Ter): A tendência continua positiva para a maioria das moedas, com alguns altos valores médios.
#
#  - Quarta-feira (Qua): A quarta-feira é um dia misto, com algumas moedas mantendo uma tendência positiva e outras
#     mostrando quedas nos valores médios.
#
#  - Quinta-feira (Qui): A tendência na quinta-feira varia, com algumas moedas mantendo valores médios elevados,   enquanto outras mostram quedas.
#
#  - Sexta-feira (Sex): A sexta-feira tende a ser um dia de queda para a maioria das moedas, com valores médios abaixo
#    da média semanal.
#
#  - Sábado (Sáb) e Domingo (Dom): O fim da semana geralmente mostra uma tendência de queda ou estabilidade nos
#    valores médios para a maioria das moedas.
#
#    Dica: essas tendências são fundamentadas em dados históricos e podem não se repetir no futuro. É importante realizar análises mais aprofundadas e considerar outros fatores ao tomar decisões de investimento em criptomoedas.

# %% [markdown]
# #5. Qual Criptomoeda se mostra MAIS interessante em relação à valorização pela análise da série histórica?

# %% [markdown]
# Entre as criptomoedas analisadas, a Aave (AAVE) se destaca como a mais interessante em termos de valorização. Com uma valorização média de 1,05%, a Aave demonstra um desempenho relativamente melhor em comparação com outras criptomoedas no período considerado. Isso pode sugerir que investidores e entusiastas da criptomoeda estão encontrando valor na Aave, tornando-a uma escolha notável no mercado.
#
# ![media_serie_historica.png](data:image/png;base64,...)

# %% [markdown]
# #6. Qual Criptomoeda se mostra MENOS interessante em relação à valorização pela análise da série histórica?
#
#
# Para responder a essa pergunta, calculamos a valorização diária média de cada criptomoeda ao longo de todo o período analisado. A valorização diária é calculada como a diferença percentual entre os preços de fechamento e abertura.
#
# A criptomoeda menos interessante em relação à valorização pela análise da série histórica é a USDCoin. Isso significa que, em média, a USDCoin teve a menor variação de preço em relação à abertura ao longo do período analisado.

# %% [markdown]
# ![download (3).png](data:image/png;base64,...)

# %% [markdown]
# #7. Existe correlação entre os valores para todas as criptomoedas?

# %% [markdown]
# ![img-correlacao.png](data:image/png;base64,...)

# %% [markdown]
# Ao analisar o gráfico de correlação entre todas as criptomoedas, observamos o seguinte:
#
# - **Correlações Positivas**: Algumas criptomoedas apresentam correlações positivas significativas entre seus valores. Isso significa que, quando o valor de uma criptomoeda aumenta, o valor de outra também tende a aumentar. Essa correlação pode indicar uma tendência geral do mercado ou fatores comuns que afetam várias criptomoedas simultaneamente.
#
# - **Correlações Negativas**: Por outro lado, também identificamos correlações negativas em alguns casos, onde o aumento no valor de uma criptomoeda está associado a uma diminuição no valor de outra. Isso pode ocorrer devido a dinâmicas de mercado complexas e é importante entender os fatores subjacentes que contribuem para essas correlações.
#
# - **Correlações Fracas**: Além das correlações fortes, existem pares de criptomoedas com correlações mais fracas, indicando que seus valores não têm uma relação direta. Isso pode ser resultado de diferentes drivers de mercado, características únicas de cada criptomoeda ou simplesmente uma falta de interação direta entre elas.
#
# Em resumo, a análise da correlação entre as criptomoedas sugere que o mercado é diversificado, com algumas moedas tendo movimentos de valor semelhantes, enquanto outras se comportam de maneira independente. É crucial aprofundar a análise para compreender as razões por trás dessas correlações e tomar decisões informadas de investimento ou estratégias de negociação com base nessa compreensão.

# %% [markdown]
# #8. [Extra] Qual é a Criptomoeda com a Maior Variação Percentual de Preço em um Único Dia?
#
# Para responder a essa pergunta, calculamos a variação percentual de preço para cada dia de negociação para todas as criptomoedas. Em seguida, identificamos o dia com a maior variação percentual e a criptomoeda correspondente.
#
# A criptomoeda com a maior variação percentual de preço em um único dia durante o período analisado é o XRP. Essa variação ocorreu em 2017-04-02 23:59:59 e foi de 178.78%, o que indica um movimento de preço significativo nesse dia.

# %% [markdown]
# ![download (2).png](data:image/png;base64,...)

# %% [markdown]
# #9. [Extra:] Qual é a média da capitalização de mercado (market cap) das criptomoedas durante o período analisado? Existe alguma criptomoeda que se destaca significativamente em termos de capitalização de mercado?

# %% [markdown]
# ![download.png](data:image/png;base64,...)

# %% [markdown]
# ## Com base na análise dos dados das criptomoedas, podemos obter os seguintes insights:
#
# - **Média da Capitalização de Mercado**: A média da capitalização de mercado das criptomoedas durante o período analisado é de aproximadamente $34,543,163,437.63. Isso representa a média do valor de mercado de todas as criptomoedas no conjunto de dados.
#
# - **Criptomoeda com Maior Capitalização de Mercado**: A criptomoeda que se destaca significativamente em termos de capitalização de mercado é o Bitcoin (BTC). Em um determinado ponto no período analisado (2021-04-13), o Bitcoin teve uma capitalização de mercado de aproximadamente $1,186,364,041,140.27, o que é substancialmente maior do que qualquer outra criptomoeda no conjunto de dados.
#
# - **Criptomoeda com Menor Capitalização de Mercado**: A criptomoeda com a menor capitalização de mercado registrada no conjunto de dados é Cosmos (ATOM). Em um determinado ponto no período analisado (2019-03-15), a capitalização de mercado do Cosmos era tão baixa que foi listada como $0. Isso indica que, nesse momento específico, o Cosmos tinha uma capitalização de mercado extremamente baixa em comparação com outras criptomoedas.
#
# - **Gráfico de Barras**: O gráfico de barras representa visualmente a capitalização de mercado de todas as criptomoedas no conjunto de dados. Ele também destaca as criptomoedas com maior e menor capitalização de mercado, facilitando a identificação das principais tendências. A linha vermelha pontilhada indica a média da capitalização de mercado, permitindo uma comparação rápida entre as criptomoedas e a média.
#
# - **Diversidade de Capitalização de Mercado**: O gráfico de barras mostra que a capitalização de mercado das criptomoedas varia significativamente, com algumas criptomoedas tendo capitalizações muito maiores do que outras. Isso reflete a diversidade do mercado de criptomoedas, onde algumas moedas têm uma presença dominante, enquanto outras têm uma presença mais modesta.
#
# No geral, esses insights destacam a importância do Bitcoin como a criptomoeda com a maior capitalização de mercado e mostram como a capitalização de mercado das criptomoedas pode variar amplamente ao longo do tempo.

# %% [markdown]
# # Conclusão
#
# Esta análise exploratória de dados fornece insights sobre o desempenho histórico das criptomoedas em relação à valorização e à variação de preço em um único dia. Essas informações são úteis para investidores e entusiastas que desejam entender melhor o comportamento desses ativos digitais.
#
# - Valores Médios das Principais Criptomoedas: Calculamos os valores médios de várias criptomoedas, incluindo Bitcoin, Ethereum, Aave, Binance Coin, Polkadot e outras. O Bitcoin lidera com o maior valor médio, destacando seu status como a criptomoeda mais valorizada. Ethereum também é uma escolha fundamental devido à sua plataforma de contratos inteligentes.
#
# - Análise de Valorização ao Longo dos Anos: Observamos as variações de preço ao longo dos anos para diferentes criptomoedas. Destacamos que 2021 foi um ano significativo de valorização para várias delas, como ChainLink, Polkadot e Cosmos.
#
# - Aave como a Mais Interessante em Termos de Valorização: Entre as criptomoedas analisadas, a Aave se destaca como a mais interessante em termos de valorização, com uma média de 1,05% de valorização. Isso sugere um interesse crescente por parte dos investidores.
#
# - USDCoin como a Menos Interessante em Termos de Valorização: A USDCoin foi identificada como a criptomoeda menos interessante em relação à valorização, pois teve a menor variação de preço em relação à abertura ao longo do período analisado.
#
# - Maior Variação Percentual de Preço em um Único Dia: O XRP teve a maior variação percentual de preço em um único dia, com uma incrível variação de 178.78% em 2017.
#
# - Capitalização de Mercado: O Bitcoin se destaca com uma capitalização de mercado substancialmente maior do que qualquer outra criptomoeda no conjunto de dados. Isso enfatiza a importância do Bitcoin no mercado de criptomoedas.
#
# - Correlação Entre as Criptomoedas: A análise da correlação entre as criptomoedas revelou que algumas têm correlações positivas, indicando movimentos de valor semelhantes, enquanto outras têm correlações negativas. Isso destaca a diversidade do mercado de criptomoedas e a complexidade de suas dinâmicas.
#
# Em resumo, o mercado de criptomoedas é diversificado e dinâmico, com algumas moedas se destacando em termos de valorização e capitalização de mercado. É crucial entender as tendências e correlações específicas para tomar decisões informadas no mundo das criptomoedas.

# %% [markdown]
# Referências :
# * USDC: https://www.novadax.com.br/criptomoedas/usdc
# * EOS: https://www.coinbase.com/pt/price/eos
# * Cosmos: https://coinext.com.br/criptomoedas/cosmos
# * ChainLink: https://coinext.com.br/criptomoedas/chainlink
# * Polkadot: https://www.infomoney.com.br/cotacoes/cripto/ativo/polkadot-dot/
# * Aave: https://www.infomoney.com.br/cotacoes/cripto/ativo/aave-aave/
# * XRP: https://exame.com/future-of-money/criptoativos/apos-anuncio-da-sec-xrp-despenca-e-token-da-ripple-e-excluido-de-exchanges/
# * Binance: https://www.binance.com/pt-BR/blog/all/binance-em-2021-inovando-em-um-mundo-cada-vez-mais-descentralizado-421499824684901885
# * Bitcoin: https://inteligenciafinanceira.com.br/aprenda/investir/quanto-vale-um-bitcoin/#:~:text=Quanto%20vale%20um%20bitcoin%20atualmente,14%2F03%2F2023).
# * Ethereum: 1) https://olhardigital.com.br/2021/11/03/pro/ethereum-dispara-e-bate-novo-recorde-de-valorizacao/
#
#     2) https://launchpad-br.ripio.com/blog/como-criar-um-nft
